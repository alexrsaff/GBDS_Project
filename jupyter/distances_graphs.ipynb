# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc= {"figure.figsize": (15, 10)})

# %% [markdown]
# # All

# %%
distances = pd.read_csv('../processed_data/distances.csv')
sns.histplot(distances.values.ravel());

# %% [markdown]
# # Inbound

# %%
distances = pd.read_csv('../processed_data/inbound_distances.csv')
sns.histplot(distances.values.ravel());

# %% [markdown]
# # Outbound

# %%
distances = pd.read_csv('../processed_data/outbound_distances.csv')
sns.histplot(distances.values.ravel());
