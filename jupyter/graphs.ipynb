# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc= {"figure.figsize": (15, 10)})

# %%
def show_graphs(data):
    data = data.set_index('time')
    avg = data.mean(axis=1)
    sns.lineplot(x=avg.index, y=avg)
    print('Average traffic through time')
    plt.show();
    avg = data.mean(axis=1)
    sns.histplot(avg)
    print('Histogram of average rides in a time chunk')
    plt.show();
    avg = data.mean(axis=0)
    sns.histplot(avg)
    print('Histogram of average rides for a station')
    plt.show();

# %% [markdown]
# # Outbound Rides

# %%
show_graphs(pd.read_csv('../processed_data/outbound.csv'))
# Out:
# Average traffic through time
# Histogram of average rides in a time chunk
# Histogram of average rides for a station

# %% [markdown]
# # Inbound Rides

# %%
show_graphs(pd.read_csv('../processed_data/inbound.csv'))
# Out:
# Average traffic through time
# Histogram of average rides in a time chunk
# Histogram of average rides for a station

# %% [markdown]
# # Combined

# %%
show_graphs(pd.read_csv('../processed_data/combined.csv'))
# Out:
# Average traffic through time
# Histogram of average rides in a time chunk
# Histogram of average rides for a station
